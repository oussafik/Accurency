# %%
from pyspark.sql import SparkSession
from pyspark.sql import Row
from pyspark.ml import PipelineModel
from pyspark.ml.tuning import CrossValidatorModel
from cassandra.cluster import Cluster
from pyspark.sql.functions import col, when
from pyspark.sql.types import StructType, StructField, StringType, TimestampType

# %%
spark = SparkSession.builder.getOrCreate()

# Load the saved pipelineFit model
pipelineFit = PipelineModel.load("pipelineFit")

# Load the saved cvModel model
cvModel = CrossValidatorModel.load("cvModel")

# %%
# Cassandra configuration
cassandra_contact_points = ['192.168.1.22']
cassandra_keyspace = 'stock_market' 
cassandra_table = 'coins_news2'

# Connect to the Cassandra cluster
cluster = Cluster(cassandra_contact_points)
session = cluster.connect()

# Switch to the keyspace
session.set_keyspace(cassandra_keyspace)

# %%
# Query to retrieve data from the table
query = f"SELECT id, timestamp, symbol, headline FROM {cassandra_table} LIMIT 250;"

# Execute the query
result_set = session.execute(query)

# %%
# Create an empty list to store the rows
result_rows = []

# Define the schema for the result DataFrame
schema = StructType([
    StructField("id", StringType(), nullable=True),
    StructField("timestamp", TimestampType(), nullable=True),
    StructField("symbol", StringType(), nullable=True),
    StructField("prediction", StringType(), nullable=True),
])

# Define a mapping for the prediction values
prediction_mapping = {0.0: "Positive", 1.0: "Neutral", 2.0: "Negative"}

# Iterate over the result_set
for row in result_set:
    # Access the values of 'id', 'timestamp', and 'symbol' columns from the row
    id_value = row.id
    timestamp_value = row.timestamp
    symbol_value = row.symbol
    
    # Create a DataFrame with the new text
    new_text_df = spark.createDataFrame([Row(clean_text=row.headline)])
    
    # Use the loaded pipelineFit to transform the new text data
    new_dataset = pipelineFit.transform(new_text_df)
    
    # Use the loaded cvModel to make predictions on the new text data
    new_predictions = cvModel.transform(new_dataset)
    
    # Access the 'prediction' column value from the new_predictions DataFrame
    prediction_value = new_predictions.select(col("prediction")).first()[0]
    
    # Map the prediction value to the corresponding label
    prediction_label = prediction_mapping.get(prediction_value, "Unknown")
    
    # Create a new row with 'id', 'timestamp', 'symbol', and 'prediction' values
    new_row = Row(id=id_value, timestamp=timestamp_value, symbol=symbol_value, prediction=prediction_label)
    print(new_row)
    # Add the new row to the result_rows list
    result_rows.append(new_row)

# Create a DataFrame from the result_rows list
new_dataframe = spark.createDataFrame(result_rows, schema)

# Display the new DataFrame
new_dataframe.show()
# Out:
# Row(id=UUID('e0cfff36-a30e-4f0c-b38b-ff9e8f72a888'), timestamp=datetime.datetime(2023, 12, 29, 0, 33), symbol='CAT', prediction='Positive')
# Row(id=UUID('c8d69e98-0a52-4a25-aa34-8dab4c16bafb'), timestamp=datetime.datetime(2023, 12, 28, 17, 0, 10), symbol='CVX', prediction='Neutral')
# Row(id=UUID('c5ca8f08-5b9f-4c9d-b214-c0abc9f84986'), timestamp=datetime.datetime(2023, 12, 30, 16, 46), symbol='CVX', prediction='Positive')
# Row(id=UUID('9d7e1d26-0b08-431a-b94e-fa96fac773ca'), timestamp=datetime.datetime(2023, 12, 29, 16, 55), symbol='GOOGL', prediction='Positive')
# Row(id=UUID('0cdc32d0-c42e-4a1f-9561-7949bf33fd69'), timestamp=datetime.datetime(2023, 12, 28, 16, 26, 11), symbol='GOOGL', prediction='Positive')
# Row(id=UUID('12f20ee2-6262-4486-ba61-e1fd831f2cff'), timestamp=datetime.datetime(2023, 12, 29, 18, 56), symbol='AMD', prediction='Negative')
# Row(id=UUID('e2a95b5d-1e68-4a4b-8e90-f7234a3aad13'), timestamp=datetime.datetime(2023, 12, 28, 19, 18, 28), symbol='GOOGL', prediction='Positive')
# Row(id=UUID('4cd7fd03-8f7c-4c17-b3e4-a849c437e0ec'), timestamp=datetime.datetime(2023, 12, 29, 20, 51, 36), symbol='GOOG', prediction='Positive')
# Row(id=UUID('bb4666a1-1dab-41e9-9227-0c59d1245805'), timestamp=datetime.datetime(2023, 12, 28, 17, 17), symbol='AAPL', prediction='Positive')
# Row(id=UUID('2728919c-8408-4adc-a7f8-2a32e3761f2a'), timestamp=datetime.datetime(2023, 12, 30, 15, 30, 1), symbol='AMD', prediction='Neutral')
# Row(id=UUID('e70c187e-4b4c-4234-ad9b-7f769dd30cad'), timestamp=datetime.datetime(2023, 12, 29, 15, 39, 6), symbol='AXP', prediction='Positive')
# Row(id=UUID('2e2ad5ec-c5bd-43b2-947a-e226801d441a'), timestamp=datetime.datetime(2023, 12, 29, 21, 35), symbol='AAPL', prediction='Positive')
# Row(id=UUID('f793d39f-28c2-4ae9-96ef-84527c2f209f'), timestamp=datetime.datetime(2023, 12, 29, 15, 9, 35), symbol='GOOG', prediction='Neutral')
# Row(id=UUID('b30f73b0-a063-4db6-af62-30c35ac4864c'), timestamp=datetime.datetime(2024, 1, 1, 0, 39), symbol='AMD', prediction='Neutral')
# Row(id=UUID('1d34d555-a92a-495b-bc61-1fb0f35a86ee'), timestamp=datetime.datetime(2023, 12, 28, 14, 23), symbol='AAPL', prediction='Positive')
# Row(id=UUID('65b8bc51-bcf0-4e99-a111-9f2228737719'), timestamp=datetime.datetime(2023, 12, 29, 22, 26), symbol='GOOG', prediction='Positive')
# Row(id=UUID('1ca30e47-2834-40d9-85dd-eef4d08838ea'), timestamp=datetime.datetime(2023, 12, 29, 16, 3), symbol='GOOGL', prediction='Neutral')
# Row(id=UUID('b0a916fb-5ea7-4f47-9678-6416070d7f2e'), timestamp=datetime.datetime(2023, 12, 30, 15, 39), symbol='AAPL', prediction='Neutral')
# Row(id=UUID('396fd7c3-2f65-40e2-9603-daeac1069b13'), timestamp=datetime.datetime(2023, 12, 28, 21, 12), symbol='BA', prediction='Positive')
# Row(id=UUID('3baa1e84-0255-4fe1-9155-3509e71f297b'), timestamp=datetime.datetime(2023, 12, 29, 16, 55), symbol='CVX', prediction='Positive')
# Row(id=UUID('f7e57993-f729-488a-b9c9-6fb1acaf2cfd'), timestamp=datetime.datetime(2023, 12, 28, 18, 55), symbol='CSCO', prediction='Neutral')
# Row(id=UUID('6861b1bc-5049-415e-b9d5-dc6aa5268c26'), timestamp=datetime.datetime(2023, 12, 28, 19, 18, 28), symbol='AXP', prediction='Positive')
# Row(id=UUID('74598263-ab30-4f1d-8b3a-d8705715fb5c'), timestamp=datetime.datetime(2023, 12, 30, 16, 16), symbol='AAPL', prediction='Positive')
# Row(id=UUID('c45b8092-533a-4c59-a089-660117494c82'), timestamp=datetime.datetime(2023, 12, 28, 18, 1), symbol='GOOG', prediction='Neutral')
# Row(id=UUID('dc1b293f-fe6f-4cd3-94fb-f709ce8ff025'), timestamp=datetime.datetime(2023, 12, 29, 22, 58), symbol='AAPL', prediction='Positive')
# Row(id=UUID('1f55115f-16b9-4468-aead-aeda72361d43'), timestamp=datetime.datetime(2023, 12, 28, 19, 18, 28), symbol='AMZN', prediction='Positive')
# Row(id=UUID('ce91f7a8-909e-4fc8-9cde-fa257449c1fa'), timestamp=datetime.datetime(2023, 12, 30, 15, 30, 1), symbol='AXP', prediction='Neutral')
# Row(id=UUID('4cc3f2c9-6417-4035-a5db-6cdf989c28bd'), timestamp=datetime.datetime(2023, 12, 31, 18, 2), symbol='AMD', prediction='Positive')
# Row(id=UUID('eedb7530-639c-4c04-84b1-75a8029edbe7'), timestamp=datetime.datetime(2023, 12, 29, 15, 30, 1), symbol='GOOG', prediction='Positive')
# Row(id=UUID('4caa839d-4262-4eb3-912d-6a5740ccf770'), timestamp=datetime.datetime(2023, 12, 30, 16, 16), symbol='CVX', prediction='Positive')
# Row(id=UUID('a3a211d9-0187-4af4-813e-193771d90d26'), timestamp=datetime.datetime(2023, 12, 30, 16, 46), symbol='CSCO', prediction='Positive')
# Row(id=UUID('b279c268-fba5-47a1-bcfe-a3fca38c75c0'), timestamp=datetime.datetime(2023, 12, 29, 21, 5), symbol='AXP', prediction='Neutral')
# Row(id=UUID('1225f818-ddc1-4b1a-bdb1-784b2dd11ab0'), timestamp=datetime.datetime(2023, 12, 28, 21, 12), symbol='CVX', prediction='Positive')
# Row(id=UUID('bedb6580-d1e2-415d-b379-5f3822d49875'), timestamp=datetime.datetime(2023, 12, 29, 15, 26, 36), symbol='GOOGL', prediction='Positive')
# Row(id=UUID('41e51afe-d1ab-4bbc-8ca6-81ef173b07eb'), timestamp=datetime.datetime(2023, 12, 29, 15, 26, 36), symbol='CVX', prediction='Positive')
# Row(id=UUID('d179c1bb-ddc3-4bfd-9fcc-51f3339ce3f3'), timestamp=datetime.datetime(2023, 12, 31, 22, 16), symbol='AMZN', prediction='Positive')
# Row(id=UUID('5fd459a7-2a6d-48c3-a764-e9af4763fb10'), timestamp=datetime.datetime(2023, 12, 29, 14, 25), symbol='CAT', prediction='Positive')
# Row(id=UUID('8d0bba96-6745-45d5-816d-234beaddc109'), timestamp=datetime.datetime(2023, 12, 29, 14, 47), symbol='AAPL', prediction='Positive')
# Row(id=UUID('571a116d-83c7-4f82-a427-d9a855aa2ae5'), timestamp=datetime.datetime(2023, 12, 28, 19, 24), symbol='AMD', prediction='Neutral')
# Row(id=UUID('63b9fe90-9319-47cb-9118-01e2b845ee49'), timestamp=datetime.datetime(2023, 12, 29, 13, 10), symbol='GOOG', prediction='Neutral')
# Row(id=UUID('883933d2-4801-462d-b09f-ee2dd6a56f8a'), timestamp=datetime.datetime(2023, 12, 29, 15, 1), symbol='GOOG', prediction='Positive')
# Row(id=UUID('fca59389-ae6f-4e39-81c1-b3ed0d504d17'), timestamp=datetime.datetime(2023, 12, 28, 14, 35, 36), symbol='GOOG', prediction='Neutral')
# Row(id=UUID('c1367928-7826-4e61-a4a6-84a9fb746aa6'), timestamp=datetime.datetime(2023, 12, 29, 13, 21), symbol='AAPL', prediction='Negative')
# Row(id=UUID('a7c34a3c-6b4e-439d-973b-2c8f8d6162dc'), timestamp=datetime.datetime(2023, 12, 28, 15, 36, 55), symbol='AAPL', prediction='Positive')
# Row(id=UUID('8bb9cd6f-c275-4df2-abfe-6b8e7e13982d'), timestamp=datetime.datetime(2023, 12, 29, 21, 0), symbol='BA', prediction='Positive')
# Row(id=UUID('8dd0bf9f-7225-4656-aac6-66911096b4b3'), timestamp=datetime.datetime(2023, 12, 29, 13, 18), symbol='GOOG', prediction='Positive')
# Row(id=UUID('2f3117f2-4123-4a04-ba6e-670220a951bb'), timestamp=datetime.datetime(2023, 12, 29, 15, 30, 1), symbol='AMD', prediction='Positive')
# Row(id=UUID('f5fc01b1-3006-4e76-b63f-3cfedc9286dd'), timestamp=datetime.datetime(2023, 12, 28, 22, 9), symbol='CVX', prediction='Neutral')
# Row(id=UUID('22c43c70-0372-40d8-bda9-03de6eec6434'), timestamp=datetime.datetime(2023, 12, 29, 13, 34), symbol='CSCO', prediction='Neutral')
# Row(id=UUID('4dcad3f6-f11e-4a3c-a002-116e416e56d1'), timestamp=datetime.datetime(2023, 12, 29, 22, 26), symbol='CAT', prediction='Positive')
# Row(id=UUID('8bc215ae-53bf-4a7a-bdf9-61ef20fa257a'), timestamp=datetime.datetime(2023, 12, 28, 20, 32), symbol='AXP', prediction='Neutral')
# Row(id=UUID('b9c6117c-fa1c-4450-85d9-f8b9256699f2'), timestamp=datetime.datetime(2023, 12, 29, 11, 0), symbol='GOOGL', prediction='Neutral')
# Row(id=UUID('9df3dd40-433c-4f1c-82e9-2c56ca8ae17a'), timestamp=datetime.datetime(2023, 12, 30, 16, 2, 32), symbol='AMD', prediction='Positive')
# Row(id=UUID('690b614f-e9f3-4731-b666-f110b35a4a9b'), timestamp=datetime.datetime(2023, 12, 29, 20, 10), symbol='AMZN', prediction='Neutral')
# Row(id=UUID('737b9135-83bb-4a2b-aa99-0915ce19b210'), timestamp=datetime.datetime(2023, 12, 29, 21, 35), symbol='AMD', prediction='Positive')
# Row(id=UUID('1c3e3af9-ecc4-4544-8750-69a97d15057a'), timestamp=datetime.datetime(2023, 12, 28, 19, 24), symbol='AMZN', prediction='Neutral')
# Row(id=UUID('b7d2beca-d471-4d7b-94ad-74ca2c151744'), timestamp=datetime.datetime(2023, 12, 28, 22, 16, 55), symbol='AXP', prediction='Positive')
# Row(id=UUID('ea57237a-6892-490d-91ce-49726ff027a5'), timestamp=datetime.datetime(2023, 12, 29, 13, 21), symbol='AMZN', prediction='Negative')
# Row(id=UUID('bcc2d482-d28b-496e-acf5-6413e2ff1c04'), timestamp=datetime.datetime(2023, 12, 28, 22, 9), symbol='AXP', prediction='Neutral')
# Row(id=UUID('02bac511-cb9c-49c9-bec9-89dbf49524cd'), timestamp=datetime.datetime(2023, 12, 28, 14, 34), symbol='GOOG', prediction='Positive')
# Row(id=UUID('aeffa80c-c32d-4f3f-8e06-3ece792d0023'), timestamp=datetime.datetime(2023, 12, 29, 20, 10), symbol='AXP', prediction='Neutral')
# Row(id=UUID('34fb6753-6b50-493a-a868-bb09abc8031c'), timestamp=datetime.datetime(2023, 12, 28, 22, 16, 55), symbol='GOOGL', prediction='Positive')
# Row(id=UUID('9df8aa9c-96dd-414d-b193-fe303caf016a'), timestamp=datetime.datetime(2023, 12, 29, 18, 56), symbol='AAPL', prediction='Negative')
# Row(id=UUID('8bb1ec47-839d-4996-b4e0-b0b3a8f81b36'), timestamp=datetime.datetime(2023, 12, 29, 13, 10), symbol='AMZN', prediction='Neutral')
# Row(id=UUID('c54bbdf1-57c7-4f2a-adb9-41c8f3b42e88'), timestamp=datetime.datetime(2023, 12, 28, 19, 24), symbol='GOOGL', prediction='Neutral')
# Row(id=UUID('9fbdb582-29f9-491d-9b31-106365b06b1e'), timestamp=datetime.datetime(2023, 12, 29, 15, 1), symbol='GOOGL', prediction='Positive')
# Row(id=UUID('c8c27b97-3ff2-4e54-897b-d2a346b8d9b6'), timestamp=datetime.datetime(2023, 12, 29, 14, 15), symbol='CAT', prediction='Positive')
# Row(id=UUID('cb007b18-0125-4967-91d9-32e85537f2ca'), timestamp=datetime.datetime(2024, 1, 1, 16, 0, 1), symbol='CSCO', prediction='Positive')
# Row(id=UUID('0d3463e9-b6b4-4ecd-8b99-c8104c1413e5'), timestamp=datetime.datetime(2023, 12, 29, 13, 0, 1), symbol='GOOGL', prediction='Positive')
# Row(id=UUID('ccc6cbab-e76b-42db-9f01-1f5bf3501a80'), timestamp=datetime.datetime(2023, 12, 28, 20, 56), symbol='CSCO', prediction='Negative')
# Row(id=UUID('23033725-b983-4e8f-8548-82e18d543d19'), timestamp=datetime.datetime(2023, 12, 31, 22, 16), symbol='BA', prediction='Positive')
# Row(id=UUID('e782b567-e5cc-49e1-a289-b0dd8698b507'), timestamp=datetime.datetime(2023, 12, 29, 14, 25), symbol='CSCO', prediction='Positive')
# Row(id=UUID('3522a9bf-862b-4f87-ae0e-f951e8ad7a1f'), timestamp=datetime.datetime(2023, 12, 31, 16, 0, 1), symbol='AXP', prediction='Positive')
# Row(id=UUID('ed177a80-3f48-4542-8c8b-9415097afdbe'), timestamp=datetime.datetime(2023, 12, 28, 17, 17), symbol='CVX', prediction='Positive')
# Row(id=UUID('0531788d-8e49-420e-817a-bd1215baa27d'), timestamp=datetime.datetime(2023, 12, 29, 13, 10), symbol='GOOGL', prediction='Neutral')
# Row(id=UUID('5f0841ad-8141-4b91-b34b-fc1c651e4fdb'), timestamp=datetime.datetime(2023, 12, 29, 20, 0), symbol='CSCO', prediction='Neutral')
# Row(id=UUID('501afc0d-3968-4915-bd2b-026c181d54db'), timestamp=datetime.datetime(2023, 12, 28, 15, 36, 55), symbol='AXP', prediction='Positive')
# Row(id=UUID('48cccb25-64e1-4f76-a66b-a9dd26e66359'), timestamp=datetime.datetime(2023, 12, 28, 13, 38), symbol='CSCO', prediction='Neutral')
# Row(id=UUID('87f31c85-36c3-4ceb-aaaa-f9e396f8fa36'), timestamp=datetime.datetime(2023, 12, 29, 21, 35), symbol='CVX', prediction='Positive')
# Row(id=UUID('f9560e28-a1b9-4a5d-8ff8-2d983b352210'), timestamp=datetime.datetime(2023, 12, 28, 19, 18, 28), symbol='AAPL', prediction='Positive')
# Row(id=UUID('e7fd84d7-cc26-4163-9d63-6766b000b5d6'), timestamp=datetime.datetime(2023, 12, 28, 14, 34), symbol='CVX', prediction='Positive')
# Row(id=UUID('69cc2204-934b-4474-8005-06cdc9687c68'), timestamp=datetime.datetime(2024, 1, 1, 15, 30, 2), symbol='AMD', prediction='Positive')
# Row(id=UUID('f7af94a2-71c0-4a48-8220-f821d2abeeae'), timestamp=datetime.datetime(2023, 12, 30, 6, 57, 58), symbol='CAT', prediction='Neutral')
# Row(id=UUID('00ad6347-89b7-409b-80db-84f639eb5bd8'), timestamp=datetime.datetime(2023, 12, 30, 16, 0, 1), symbol='BA', prediction='Positive')
# Row(id=UUID('76d9f5d4-a68a-47b8-9aef-d4fd35b5094d'), timestamp=datetime.datetime(2023, 12, 29, 14, 10), symbol='AAPL', prediction='Positive')
# Row(id=UUID('8226d06f-e6a6-44e3-b4df-7502b1d32383'), timestamp=datetime.datetime(2023, 12, 29, 16, 3), symbol='CAT', prediction='Neutral')
# Row(id=UUID('36649ed7-a625-461a-b338-133cbcb5f321'), timestamp=datetime.datetime(2023, 12, 28, 14, 34), symbol='AXP', prediction='Positive')
# Row(id=UUID('d588e4a5-9123-4d38-be7e-66adc6634528'), timestamp=datetime.datetime(2023, 12, 28, 18, 55), symbol='AXP', prediction='Neutral')
# Row(id=UUID('c3dda8b3-554b-4f33-905a-81e41599a37a'), timestamp=datetime.datetime(2023, 12, 29, 20, 5), symbol='CVX', prediction='Neutral')
# Row(id=UUID('32d4287b-dcdd-4776-a1bf-8d66a0c4c160'), timestamp=datetime.datetime(2023, 12, 29, 20, 0), symbol='CAT', prediction='Neutral')
# Row(id=UUID('43f3d0c1-751a-4c5f-9ee5-cc55b3533ed2'), timestamp=datetime.datetime(2023, 12, 29, 15, 1), symbol='CVX', prediction='Positive')
# Row(id=UUID('c5a08066-5428-4303-b674-7655c30144f3'), timestamp=datetime.datetime(2023, 12, 31, 17, 12, 43), symbol='AMD', prediction='Neutral')
# Row(id=UUID('69654156-96ee-4810-8142-8bf90ef231ce'), timestamp=datetime.datetime(2023, 12, 28, 20, 5, 50), symbol='AXP', prediction='Positive')
# Row(id=UUID('9da7d844-0a94-4c1d-800f-b9cf86ea93c2'), timestamp=datetime.datetime(2023, 12, 28, 14, 35, 36), symbol='BA', prediction='Neutral')
# Row(id=UUID('2969dd86-2f12-4326-b9c3-1f1bfc2f02ed'), timestamp=datetime.datetime(2023, 12, 29, 18, 59), symbol='CSCO', prediction='Positive')
# Row(id=UUID('86738685-9c5e-4230-9f8a-925cf32d5307'), timestamp=datetime.datetime(2024, 1, 1, 15, 30, 2), symbol='CSCO', prediction='Positive')
# Row(id=UUID('98d6afeb-2202-474e-bff9-02b68544cd6c'), timestamp=datetime.datetime(2023, 12, 28, 21, 12), symbol='AXP', prediction='Positive')
# Row(id=UUID('fbda6d81-cb51-4fbf-920f-4ff1e313300f'), timestamp=datetime.datetime(2024, 1, 1, 0, 39), symbol='AAPL', prediction='Neutral')
# Row(id=UUID('ff3b0cab-0dfa-4b06-a605-3fff1079584e'), timestamp=datetime.datetime(2023, 12, 28, 16, 0), symbol='CAT', prediction='Neutral')
# Row(id=UUID('d3edf60c-5c71-4b1e-9103-7682005858df'), timestamp=datetime.datetime(2023, 12, 29, 20, 10), symbol='AMD', prediction='Neutral')
# Row(id=UUID('7854a95d-dd93-4a55-9582-de94f39e920c'), timestamp=datetime.datetime(2023, 12, 30, 16, 2, 32), symbol='CVX', prediction='Positive')
# Row(id=UUID('6a5c53c0-a56b-4d4b-8489-0d6ec564ce0b'), timestamp=datetime.datetime(2023, 12, 29, 11, 0), symbol='AAPL', prediction='Neutral')
# Row(id=UUID('0827da87-6f72-43d3-8d1e-19d3a1843088'), timestamp=datetime.datetime(2023, 12, 29, 15, 39, 6), symbol='GOOG', prediction='Positive')
# Row(id=UUID('1221b72d-bbf3-484e-871d-2fb11172fb3d'), timestamp=datetime.datetime(2023, 12, 28, 18, 55), symbol='CVX', prediction='Neutral')
# Row(id=UUID('8a7bb13b-d00a-4b66-8cea-27edcd88b3f8'), timestamp=datetime.datetime(2023, 12, 31, 22, 16), symbol='GOOG', prediction='Positive')
# Row(id=UUID('903dd7ce-4f24-4307-abf4-be1f696fd608'), timestamp=datetime.datetime(2023, 12, 28, 20, 5, 50), symbol='BA', prediction='Positive')
# Row(id=UUID('535e6665-e873-4796-a98a-8f0a785eb5b3'), timestamp=datetime.datetime(2023, 12, 29, 17, 18), symbol='CAT', prediction='Negative')
# Row(id=UUID('777a18c2-a71e-42eb-9ef0-e478b95d696d'), timestamp=datetime.datetime(2023, 12, 31, 22, 16), symbol='CVX', prediction='Positive')
# Row(id=UUID('8bb2c625-8262-4573-a28f-0518c0fdc73c'), timestamp=datetime.datetime(2023, 12, 29, 15, 1), symbol='AAPL', prediction='Positive')
# Row(id=UUID('f97ac3e8-fe69-49ec-a519-f4b095448b50'), timestamp=datetime.datetime(2023, 12, 29, 20, 5), symbol='GOOG', prediction='Neutral')
# Row(id=UUID('496a09c9-8f82-436a-979f-3d4173c7c4cf'), timestamp=datetime.datetime(2023, 12, 28, 20, 5, 50), symbol='AAPL', prediction='Positive')
# Row(id=UUID('2f7a6f5f-c901-4de1-a762-37cfa4146b47'), timestamp=datetime.datetime(2023, 12, 28, 18, 1), symbol='CAT', prediction='Neutral')
# Row(id=UUID('324b9a3b-63b9-4a12-b7ef-2b1c39072e03'), timestamp=datetime.datetime(2023, 12, 31, 17, 0, 1), symbol='AXP', prediction='Positive')
# Row(id=UUID('b8e82052-6984-41bb-a670-f5933d593ae2'), timestamp=datetime.datetime(2023, 12, 29, 18, 59), symbol='AXP', prediction='Positive')
# Row(id=UUID('2738761b-7744-4b63-a86c-22c7890c2aa5'), timestamp=datetime.datetime(2023, 12, 30, 16, 0, 1), symbol='CVX', prediction='Positive')
# Row(id=UUID('73fae8f0-e42d-4e11-88a7-f42230b751a9'), timestamp=datetime.datetime(2023, 12, 29, 14, 30), symbol='AMZN', prediction='Neutral')
# Row(id=UUID('7dc2e278-6178-4852-93a0-42d408e12247'), timestamp=datetime.datetime(2023, 12, 29, 16, 55), symbol='GOOG', prediction='Positive')
# Row(id=UUID('8aee8012-9dca-40f6-884f-e4a76d05daef'), timestamp=datetime.datetime(2023, 12, 29, 17, 18), symbol='CVX', prediction='Negative')
# Row(id=UUID('f45d12cb-5ccc-4df3-9e4a-ca3b258e4836'), timestamp=datetime.datetime(2024, 1, 1, 15, 30, 2), symbol='BA', prediction='Positive')
# Row(id=UUID('e34d79ac-8ee5-40a5-a15b-45ff2774ef74'), timestamp=datetime.datetime(2023, 12, 29, 11, 0), symbol='AAPL', prediction='Neutral')
# Row(id=UUID('f8abbd81-13a3-4c66-b498-7f6e5d74bbc6'), timestamp=datetime.datetime(2023, 12, 29, 18, 59), symbol='AAPL', prediction='Positive')
# Row(id=UUID('60ef24ff-24b8-4ad2-bcc7-f29eeb089bd1'), timestamp=datetime.datetime(2023, 12, 28, 17, 2), symbol='BA', prediction='Neutral')
# Row(id=UUID('eb6b6720-013c-43da-823c-3b8eff257e7f'), timestamp=datetime.datetime(2023, 12, 29, 14, 25), symbol='GOOGL', prediction='Positive')
# Row(id=UUID('2270e029-53bc-4acf-83c6-424f8f386947'), timestamp=datetime.datetime(2023, 12, 29, 18, 59), symbol='GOOG', prediction='Positive')
# Row(id=UUID('4291680b-a2e8-4fbe-ad90-3144d8d774ed'), timestamp=datetime.datetime(2023, 12, 29, 17, 13, 37), symbol='GOOG', prediction='Neutral')
# Row(id=UUID('23616f57-4547-405d-8485-4a5c0c503513'), timestamp=datetime.datetime(2023, 12, 29, 13, 18), symbol='AAPL', prediction='Positive')
# Row(id=UUID('9096143a-a3c8-47a8-80c4-ffe0bc4de62b'), timestamp=datetime.datetime(2023, 12, 28, 18, 1), symbol='CVX', prediction='Neutral')
# Row(id=UUID('346ed177-1dd0-4158-ac66-0ec6872b854c'), timestamp=datetime.datetime(2023, 12, 30, 16, 2, 32), symbol='GOOGL', prediction='Positive')
# Row(id=UUID('83da4ef0-d75f-4ba1-847a-1b7bd370f85e'), timestamp=datetime.datetime(2023, 12, 28, 18, 48, 1), symbol='AXP', prediction='Positive')
# Row(id=UUID('f23f74a0-618e-4b12-926e-d6eccc315da0'), timestamp=datetime.datetime(2023, 12, 30, 15, 39), symbol='AMD', prediction='Neutral')
# Row(id=UUID('699f404d-8427-4a1a-bfd2-d03f9646e86e'), timestamp=datetime.datetime(2023, 12, 29, 19, 39), symbol='GOOG', prediction='Positive')
# Row(id=UUID('75f3f7af-ead0-4b66-9a64-fd110a40ba7e'), timestamp=datetime.datetime(2023, 12, 29, 22, 58), symbol='BA', prediction='Positive')
# Row(id=UUID('0a38143b-d375-4ae5-8cc3-0f2c74a1cc21'), timestamp=datetime.datetime(2023, 12, 29, 14, 47), symbol='AXP', prediction='Positive')
# Row(id=UUID('3c230847-8b1d-4e28-b449-6780f25a0bf5'), timestamp=datetime.datetime(2023, 12, 31, 16, 1), symbol='CVX', prediction='Neutral')
# Row(id=UUID('956972a9-0406-4d6b-969d-a55d20e6edc1'), timestamp=datetime.datetime(2023, 12, 29, 13, 21), symbol='AXP', prediction='Negative')
# Row(id=UUID('88512288-881e-432b-abdb-e6e65755a63d'), timestamp=datetime.datetime(2023, 12, 29, 20, 10), symbol='CSCO', prediction='Neutral')
# Row(id=UUID('11f24aa9-91fd-40a0-8db5-88d7790ad025'), timestamp=datetime.datetime(2023, 12, 30, 16, 0, 1), symbol='AXP', prediction='Positive')
# Row(id=UUID('0c6604c7-8916-4037-a576-d07a9d012c4e'), timestamp=datetime.datetime(2023, 12, 31, 15, 0, 1), symbol='AAPL', prediction='Positive')
# Row(id=UUID('87e1bc10-3f97-4711-8631-08ae50aef2c7'), timestamp=datetime.datetime(2023, 12, 29, 16, 35), symbol='AMD', prediction='Positive')
# Row(id=UUID('afbfa06c-1568-44bc-b2f1-cabc3563bb42'), timestamp=datetime.datetime(2023, 12, 30, 3, 49, 2), symbol='GOOG', prediction='Positive')
# Row(id=UUID('c3d02a64-acf4-49f4-9090-cc72cb60bc24'), timestamp=datetime.datetime(2024, 1, 1, 15, 30, 2), symbol='GOOGL', prediction='Positive')
# Row(id=UUID('0bee699d-8011-4e17-9129-a03159073f33'), timestamp=datetime.datetime(2023, 12, 30, 3, 49, 2), symbol='CVX', prediction='Positive')
# Row(id=UUID('f949bf4e-92ac-4ced-9f63-c00f14f621a0'), timestamp=datetime.datetime(2023, 12, 31, 17, 0, 1), symbol='AMZN', prediction='Positive')
# Row(id=UUID('acd231c8-d63a-4f9d-9915-c7aa20a779da'), timestamp=datetime.datetime(2023, 12, 28, 20, 56), symbol='AMD', prediction='Negative')
# Row(id=UUID('9ccf7e6a-0ed5-4b40-addd-53bcbf048f83'), timestamp=datetime.datetime(2023, 12, 30, 6, 57, 58), symbol='AAPL', prediction='Neutral')
# Row(id=UUID('7c3efcb0-c292-4724-952d-e99063732908'), timestamp=datetime.datetime(2023, 12, 28, 18, 55), symbol='AMD', prediction='Neutral')
# Row(id=UUID('71ca7123-dec9-458f-a9c0-9ec3f30b8d68'), timestamp=datetime.datetime(2023, 12, 30, 16, 0, 1), symbol='GOOG', prediction='Positive')
# Row(id=UUID('8ed97b78-b87e-458b-ab2c-2da5ddd516dd'), timestamp=datetime.datetime(2023, 12, 29, 12, 44), symbol='GOOGL', prediction='Positive')
# Row(id=UUID('0bc3c5fb-3b6d-4e69-a754-252c15b1cabe'), timestamp=datetime.datetime(2023, 12, 29, 17, 18), symbol='GOOG', prediction='Negative')
# Row(id=UUID('e006c587-06f9-4bd6-8257-c4ae9ad5f0fa'), timestamp=datetime.datetime(2024, 1, 1, 15, 30, 2), symbol='CAT', prediction='Positive')
# Row(id=UUID('a8604240-30eb-4495-910a-360a302def0e'), timestamp=datetime.datetime(2023, 12, 29, 13, 0, 1), symbol='AMZN', prediction='Positive')
# Row(id=UUID('99e52c5c-9c8c-498e-a4ca-ec5a44800699'), timestamp=datetime.datetime(2023, 12, 29, 21, 20), symbol='BA', prediction='Neutral')
# Row(id=UUID('b8416d7b-55cb-4ca6-8bf8-fdd6cb49398d'), timestamp=datetime.datetime(2023, 12, 30, 16, 16), symbol='GOOG', prediction='Positive')
# Row(id=UUID('3d807767-703d-49ca-bb5d-62e779a32de9'), timestamp=datetime.datetime(2023, 12, 28, 16, 0), symbol='GOOG', prediction='Neutral')
# Row(id=UUID('f525d3d9-c6f9-42c2-b336-3f93a04e5009'), timestamp=datetime.datetime(2023, 12, 28, 14, 23), symbol='BA', prediction='Positive')
# Row(id=UUID('36c71a7a-ab8d-400e-9d0f-2faeab4044a4'), timestamp=datetime.datetime(2023, 12, 28, 20, 5, 50), symbol='AMZN', prediction='Positive')
# Row(id=UUID('678ebe34-2f24-480f-8bb5-361372796b97'), timestamp=datetime.datetime(2023, 12, 29, 16, 3), symbol='AMD', prediction='Neutral')
# Row(id=UUID('5ad9ac70-68e7-435e-a657-2af1967ef893'), timestamp=datetime.datetime(2023, 12, 29, 13, 10), symbol='CVX', prediction='Neutral')
# Row(id=UUID('705854c4-f46c-4f79-a5c0-af82fbb40775'), timestamp=datetime.datetime(2023, 12, 29, 17, 13, 37), symbol='CSCO', prediction='Neutral')
# Row(id=UUID('97452990-4b67-4b50-9594-e45e1e11991d'), timestamp=datetime.datetime(2023, 12, 30, 13, 31), symbol='CVX', prediction='Positive')
# Row(id=UUID('57bf3e87-6357-482a-bbea-ded82cb08cfd'), timestamp=datetime.datetime(2023, 12, 30, 15, 30, 1), symbol='AMZN', prediction='Neutral')
# Row(id=UUID('9d2f244c-4d8f-444e-a7c3-5e13f1cdd083'), timestamp=datetime.datetime(2023, 12, 29, 21, 35), symbol='GOOG', prediction='Positive')
# Row(id=UUID('3f67eb23-8ad9-4009-a5be-aa4c7de4ef77'), timestamp=datetime.datetime(2023, 12, 28, 21, 51), symbol='CSCO', prediction='Negative')
# Row(id=UUID('e48ff586-6a4a-42eb-a0e8-a1e89020c134'), timestamp=datetime.datetime(2023, 12, 29, 12, 36), symbol='CAT', prediction='Positive')
# Row(id=UUID('10888248-e531-47da-98eb-006b1e892924'), timestamp=datetime.datetime(2023, 12, 28, 18, 48, 1), symbol='GOOG', prediction='Positive')
# Row(id=UUID('2ec464eb-f6ca-477d-bada-bfcd3760c797'), timestamp=datetime.datetime(2023, 12, 28, 19, 18, 28), symbol='CAT', prediction='Positive')
# Row(id=UUID('eb562d77-69a9-4745-8f60-7fd0fda65e8e'), timestamp=datetime.datetime(2023, 12, 30, 14, 0, 1), symbol='BA', prediction='Positive')
# Row(id=UUID('d4902fc3-a7ea-4338-bb91-b0d5e0f3072f'), timestamp=datetime.datetime(2023, 12, 29, 15, 39, 6), symbol='AMZN', prediction='Positive')
# Row(id=UUID('1b2e9d5a-7db4-4f06-acee-c6cc6db2c2ae'), timestamp=datetime.datetime(2024, 1, 1, 5, 22, 59), symbol='CAT', prediction='Neutral')
# Row(id=UUID('6effc216-d8dd-4f82-b493-60bdadc9ee00'), timestamp=datetime.datetime(2023, 12, 29, 14, 10), symbol='BA', prediction='Positive')
# Row(id=UUID('49b94a21-ca26-49fb-b028-bd21ef8f2aa1'), timestamp=datetime.datetime(2023, 12, 31, 15, 0, 1), symbol='AMD', prediction='Positive')
# Row(id=UUID('01301de9-ad77-41ae-86cf-642a0a58f1f6'), timestamp=datetime.datetime(2023, 12, 30, 13, 31), symbol='AMD', prediction='Positive')
# Row(id=UUID('c3815714-b45f-42e6-82e0-20aa5579debc'), timestamp=datetime.datetime(2023, 12, 29, 11, 0), symbol='AXP', prediction='Neutral')
# Row(id=UUID('77b21c46-b609-483d-a30b-5cff8353d4f3'), timestamp=datetime.datetime(2023, 12, 28, 13, 38), symbol='GOOGL', prediction='Neutral')
# Row(id=UUID('1ed6bf4a-2a21-4aad-984d-f39cebf652f1'), timestamp=datetime.datetime(2023, 12, 29, 14, 15), symbol='AMD', prediction='Positive')
# Row(id=UUID('e9823f37-5161-402e-b228-eea15ccd7362'), timestamp=datetime.datetime(2023, 12, 29, 20, 10), symbol='GOOGL', prediction='Neutral')
# Row(id=UUID('68f2cac7-2259-43c3-9212-9160e9f443ed'), timestamp=datetime.datetime(2023, 12, 29, 12, 44), symbol='AMZN', prediction='Positive')
# Row(id=UUID('af2a562e-2a50-40f0-b4ce-47f90ff48dbc'), timestamp=datetime.datetime(2023, 12, 29, 14, 10), symbol='GOOGL', prediction='Positive')
# Row(id=UUID('5d771e13-4e30-4a78-9006-67c2216d514b'), timestamp=datetime.datetime(2023, 12, 29, 14, 47), symbol='GOOGL', prediction='Positive')
# Row(id=UUID('ce08e929-2450-4b3c-8fc1-c388122328aa'), timestamp=datetime.datetime(2023, 12, 29, 22, 26), symbol='AAPL', prediction='Positive')
# Row(id=UUID('9bd82144-0d3d-4b1a-86f2-09c6f32d5e0a'), timestamp=datetime.datetime(2023, 12, 30, 15, 39), symbol='AMZN', prediction='Neutral')
# Row(id=UUID('20e880a0-54ae-4a79-af7f-f5948822dadb'), timestamp=datetime.datetime(2023, 12, 29, 0, 33), symbol='AMD', prediction='Positive')
# Row(id=UUID('226de5c9-164d-4f5f-b7c8-5051584f780f'), timestamp=datetime.datetime(2023, 12, 30, 15, 0, 1), symbol='CAT', prediction='Positive')
# Row(id=UUID('e5b4c258-25f5-44df-ba7e-b5eb91fd57b5'), timestamp=datetime.datetime(2024, 1, 1, 0, 39), symbol='AXP', prediction='Neutral')
# Row(id=UUID('1c3d41fa-781e-47fc-b6ad-15edce6429a1'), timestamp=datetime.datetime(2023, 12, 29, 22, 58), symbol='AMD', prediction='Positive')
# Row(id=UUID('c606369a-a429-43ea-8745-ed3449a6407f'), timestamp=datetime.datetime(2023, 12, 31, 17, 0, 1), symbol='CAT', prediction='Positive')
# Row(id=UUID('50a4698e-9c66-429d-ab66-0a96a6fd5656'), timestamp=datetime.datetime(2023, 12, 28, 16, 26, 11), symbol='AMD', prediction='Positive')
# Row(id=UUID('a299c685-c005-4912-98eb-c75a493e06b5'), timestamp=datetime.datetime(2023, 12, 29, 20, 51, 36), symbol='AMZN', prediction='Positive')
# Row(id=UUID('7487854f-4702-4626-af93-9ac0fc15dffb'), timestamp=datetime.datetime(2024, 1, 1, 15, 30, 2), symbol='AXP', prediction='Positive')
# Row(id=UUID('5cba18be-c781-49a0-924f-e195ba9a0172'), timestamp=datetime.datetime(2023, 12, 29, 13, 21), symbol='CVX', prediction='Negative')
# Row(id=UUID('44ae508d-3620-449a-88e0-28b3ed4b4c4b'), timestamp=datetime.datetime(2023, 12, 29, 21, 29), symbol='BA', prediction='Positive')
# Row(id=UUID('95891589-28e4-48fe-a558-2ddb112c3cf4'), timestamp=datetime.datetime(2023, 12, 29, 19, 39), symbol='CVX', prediction='Positive')
# Row(id=UUID('5599dec0-ee63-496f-81ea-cccce0279d0e'), timestamp=datetime.datetime(2023, 12, 28, 22, 9), symbol='AMZN', prediction='Neutral')
# Row(id=UUID('0ae1b5f2-f3dd-4693-87ab-8ef7bf720203'), timestamp=datetime.datetime(2023, 12, 29, 0, 33), symbol='GOOG', prediction='Positive')
# Row(id=UUID('66743190-0bde-4731-8733-10983e89edad'), timestamp=datetime.datetime(2023, 12, 31, 17, 12, 43), symbol='GOOGL', prediction='Neutral')
# Row(id=UUID('1d11c3f8-6485-4d81-8de7-cfe81c8d6b39'), timestamp=datetime.datetime(2023, 12, 29, 11, 0), symbol='CVX', prediction='Neutral')
# Row(id=UUID('484919fb-e0f4-4808-961d-aaec7a017afb'), timestamp=datetime.datetime(2023, 12, 29, 13, 18), symbol='AMZN', prediction='Positive')
# Row(id=UUID('58a3839b-f6fa-45cb-9b7b-fccf9e56fec6'), timestamp=datetime.datetime(2023, 12, 30, 18, 43, 58), symbol='CSCO', prediction='Neutral')
# Row(id=UUID('1577a544-c9b2-4c7c-bcd1-4fecb5acb777'), timestamp=datetime.datetime(2024, 1, 1, 15, 30, 2), symbol='AMD', prediction='Positive')
# Row(id=UUID('cfe785b4-72ca-4fdd-957a-ff27c03689c8'), timestamp=datetime.datetime(2023, 12, 29, 12, 44), symbol='AAPL', prediction='Positive')
# Row(id=UUID('6d9cb490-824d-41d8-b8d3-cf204abe2c6a'), timestamp=datetime.datetime(2023, 12, 31, 15, 0, 1), symbol='BA', prediction='Positive')
# Row(id=UUID('c7ad3018-e074-4df0-b6ab-79365ba2156b'), timestamp=datetime.datetime(2023, 12, 28, 14, 34), symbol='AMD', prediction='Positive')
# Row(id=UUID('95394e72-12c7-4f6e-9e01-bc9968d0af5d'), timestamp=datetime.datetime(2023, 12, 30, 18, 43, 58), symbol='BA', prediction='Neutral')
# Row(id=UUID('8a3bb6ce-e377-4ab4-ba39-10049992d32b'), timestamp=datetime.datetime(2024, 1, 1, 15, 30, 2), symbol='AMZN', prediction='Positive')
# Row(id=UUID('97faff93-f65d-4e5b-b2ba-1d1b40789e6c'), timestamp=datetime.datetime(2023, 12, 30, 15, 30, 1), symbol='CSCO', prediction='Neutral')
# Row(id=UUID('603f084b-d2e3-47a4-b9df-11cd34c9d181'), timestamp=datetime.datetime(2023, 12, 31, 17, 0, 1), symbol='BA', prediction='Positive')
# Row(id=UUID('f19f96bf-fe79-4ab2-8f47-79d78b9ea32b'), timestamp=datetime.datetime(2023, 12, 29, 14, 30), symbol='CSCO', prediction='Neutral')
# Row(id=UUID('d1d07a63-aed4-4234-8589-f8fdbf5d73f7'), timestamp=datetime.datetime(2023, 12, 30, 16, 46), symbol='CAT', prediction='Positive')
# Row(id=UUID('873939e0-cc05-4a49-affa-5719c9f30dde'), timestamp=datetime.datetime(2023, 12, 30, 3, 49, 2), symbol='AXP', prediction='Positive')
# Row(id=UUID('97b36630-8e9b-47c1-a30d-70c282aa47de'), timestamp=datetime.datetime(2023, 12, 29, 19, 40, 5), symbol='AMZN', prediction='Positive')
# Row(id=UUID('34ec80f5-4199-4e3f-9191-a14ab717f41a'), timestamp=datetime.datetime(2023, 12, 29, 20, 51, 36), symbol='CSCO', prediction='Positive')
# Row(id=UUID('164aad0a-d99a-42d9-b696-3f4d051ce479'), timestamp=datetime.datetime(2023, 12, 29, 0, 40), symbol='AAPL', prediction='Neutral')
# Row(id=UUID('94aa2501-0e9e-4823-9681-77fdc9f53f35'), timestamp=datetime.datetime(2023, 12, 31, 18, 2), symbol='CAT', prediction='Positive')
# Row(id=UUID('ae6013ae-13af-4783-a6a0-1274beafe983'), timestamp=datetime.datetime(2023, 12, 29, 19, 40, 5), symbol='CSCO', prediction='Positive')
# Row(id=UUID('a6a9bd91-07b0-4bf3-b76a-1f59d6d7ac9d'), timestamp=datetime.datetime(2023, 12, 29, 17, 48), symbol='CAT', prediction='Positive')
# Row(id=UUID('0e20c890-f2c5-4eaf-ac93-d0824d36a13e'), timestamp=datetime.datetime(2023, 12, 29, 21, 29), symbol='AAPL', prediction='Positive')
# Row(id=UUID('8bb67e0f-f27b-49f3-979b-c421f85d4bbd'), timestamp=datetime.datetime(2023, 12, 28, 22, 16, 55), symbol='CAT', prediction='Positive')
# Row(id=UUID('e4c9a34e-66da-414a-9120-7dff01bb7472'), timestamp=datetime.datetime(2023, 12, 28, 17, 2), symbol='AMD', prediction='Neutral')
# Row(id=UUID('61a6a003-d225-4ecd-8ab2-e9c0c54fd350'), timestamp=datetime.datetime(2023, 12, 30, 14, 2), symbol='GOOG', prediction='Positive')
# Row(id=UUID('2d83899b-977a-43bb-8c72-774708fac6db'), timestamp=datetime.datetime(2023, 12, 29, 19, 11, 8), symbol='CAT', prediction='Positive')
# Row(id=UUID('1c0236b0-6f34-42e8-beec-a49a32c2ef15'), timestamp=datetime.datetime(2023, 12, 29, 21, 20), symbol='AMZN', prediction='Neutral')
# Row(id=UUID('cc97d654-23f0-4c4d-9941-59d03b9c498d'), timestamp=datetime.datetime(2023, 12, 29, 13, 34), symbol='BA', prediction='Neutral')
# Row(id=UUID('5599e5dd-819b-42ca-97e1-c16d3a90440c'), timestamp=datetime.datetime(2023, 12, 29, 15, 30, 1), symbol='BA', prediction='Positive')
# Row(id=UUID('ed81071a-3580-4bd1-98fb-f177646d6fb1'), timestamp=datetime.datetime(2023, 12, 28, 17, 0, 10), symbol='AMZN', prediction='Neutral')
# Row(id=UUID('4db1ad14-7d33-493a-b46b-4215e35e00f4'), timestamp=datetime.datetime(2023, 12, 28, 14, 34), symbol='GOOGL', prediction='Positive')
# Row(id=UUID('b0c4fe27-d6fd-46cf-a3cc-e993197d7476'), timestamp=datetime.datetime(2023, 12, 31, 22, 16), symbol='AAPL', prediction='Positive')
# Row(id=UUID('775a89a0-86e5-4ec1-b878-ac4b5f0e47d0'), timestamp=datetime.datetime(2023, 12, 31, 15, 0, 1), symbol='GOOGL', prediction='Positive')
# Row(id=UUID('3aa8c4cd-da09-4415-add3-1beace425517'), timestamp=datetime.datetime(2023, 12, 29, 16, 3), symbol='BA', prediction='Neutral')
# Row(id=UUID('8476839f-5f73-4d80-b991-4a585f3e2ae2'), timestamp=datetime.datetime(2023, 12, 29, 18, 56), symbol='GOOG', prediction='Negative')
# Row(id=UUID('6c488025-118b-4ea6-bd05-402d708d3770'), timestamp=datetime.datetime(2023, 12, 28, 20, 5, 50), symbol='GOOG', prediction='Positive')
# Row(id=UUID('8722d534-a4b6-4c79-ad17-9003346e18d1'), timestamp=datetime.datetime(2023, 12, 29, 19, 17), symbol='AMD', prediction='Negative')
# Row(id=UUID('784ea395-c5fe-4b1b-84d8-342d828a15f2'), timestamp=datetime.datetime(2023, 12, 30, 14, 2), symbol='BA', prediction='Positive')
# Row(id=UUID('5c201e74-644a-402b-96c8-5a2fb7c69b84'), timestamp=datetime.datetime(2023, 12, 28, 19, 18, 28), symbol='AMD', prediction='Positive')
# Row(id=UUID('f3ad5897-dc64-461b-af0b-69a8a3d47f02'), timestamp=datetime.datetime(2023, 12, 28, 17, 0, 10), symbol='AMD', prediction='Neutral')
# Row(id=UUID('a801c70d-644c-438f-bb42-3b9f851a7f14'), timestamp=datetime.datetime(2023, 12, 30, 18, 43, 58), symbol='AAPL', prediction='Neutral')
# Row(id=UUID('e88673eb-b656-4bd8-9772-f4ec4c441548'), timestamp=datetime.datetime(2023, 12, 29, 20, 0), symbol='AAPL', prediction='Neutral')
# Row(id=UUID('b345407a-aec7-4311-b141-daaa52db6a2d'), timestamp=datetime.datetime(2023, 12, 28, 15, 10, 1), symbol='BA', prediction='Positive')
# Row(id=UUID('13edac92-5cbb-43b9-be3a-b7373566b42a'), timestamp=datetime.datetime(2024, 1, 1, 15, 30, 2), symbol='BA', prediction='Positive')
# Row(id=UUID('19015f6b-9b34-4076-bcb9-43166b9d2ff5'), timestamp=datetime.datetime(2024, 1, 1, 15, 30, 2), symbol='GOOGL', prediction='Positive')
# Row(id=UUID('e534a031-0407-44ba-8da7-5d099d544103'), timestamp=datetime.datetime(2023, 12, 28, 22, 9), symbol='BA', prediction='Neutral')
# Row(id=UUID('9841bbba-c6fd-4cbd-8e73-b07eefc6feed'), timestamp=datetime.datetime(2023, 12, 30, 15, 0, 1), symbol='CVX', prediction='Positive')
# Row(id=UUID('f45d3601-ed08-46bd-a532-77dfd3123935'), timestamp=datetime.datetime(2023, 12, 30, 21, 55, 14), symbol='AAPL', prediction='Neutral')
# Row(id=UUID('bcfce33b-0c17-4329-97f1-836c7ed56ac4'), timestamp=datetime.datetime(2023, 12, 29, 13, 18), symbol='CSCO', prediction='Positive')
# Row(id=UUID('5102f45e-f3d9-4a0a-a099-93541a3d45bd'), timestamp=datetime.datetime(2023, 12, 30, 21, 55, 14), symbol='AMZN', prediction='Neutral')
# Row(id=UUID('24a86644-4201-4df6-bb7f-4100ebd2dc89'), timestamp=datetime.datetime(2023, 12, 29, 19, 17), symbol='BA', prediction='Negative')
# Row(id=UUID('00701a00-bfb3-4606-b85f-1ba81b701c15'), timestamp=datetime.datetime(2023, 12, 29, 19, 11, 8), symbol='AAPL', prediction='Positive')
# Row(id=UUID('3ce220d7-d14c-47e4-91f0-fd3bfeec4267'), timestamp=datetime.datetime(2023, 12, 30, 15, 0, 1), symbol='CSCO', prediction='Positive')
# Row(id=UUID('71a638e5-60f2-4aa9-817c-fdbc509cb6c4'), timestamp=datetime.datetime(2023, 12, 30, 15, 39), symbol='GOOGL', prediction='Neutral')
# Row(id=UUID('1e090dd0-9e29-4eab-a438-2ccaf0a9c09b'), timestamp=datetime.datetime(2023, 12, 29, 19, 39), symbol='AAPL', prediction='Positive')
# Row(id=UUID('d32cfcc8-a9fe-4633-b1b3-808c0f261f02'), timestamp=datetime.datetime(2023, 12, 28, 20, 32), symbol='AAPL', prediction='Neutral')
# +--------------------+-------------------+------+----------+
# |                  id|          timestamp|symbol|prediction|
# +--------------------+-------------------+------+----------+
# |{__class__=uuid.U...|2023-12-29 00:33:00|   CAT|  Positive|
# |{__class__=uuid.U...|2023-12-28 17:00:10|   CVX|   Neutral|
# |{__class__=uuid.U...|2023-12-30 16:46:00|   CVX|  Positive|
# |{__class__=uuid.U...|2023-12-29 16:55:00| GOOGL|  Positive|
# |{__class__=uuid.U...|2023-12-28 16:26:11| GOOGL|  Positive|
# |{__class__=uuid.U...|2023-12-29 18:56:00|   AMD|  Negative|
# |{__class__=uuid.U...|2023-12-28 19:18:28| GOOGL|  Positive|
# |{__class__=uuid.U...|2023-12-29 20:51:36|  GOOG|  Positive|
# |{__class__=uuid.U...|2023-12-28 17:17:00|  AAPL|  Positive|
# |{__class__=uuid.U...|2023-12-30 15:30:01|   AMD|   Neutral|
# |{__class__=uuid.U...|2023-12-29 15:39:06|   AXP|  Positive|
# |{__class__=uuid.U...|2023-12-29 21:35:00|  AAPL|  Positive|
# |{__class__=uuid.U...|2023-12-29 15:09:35|  GOOG|   Neutral|
# |{__class__=uuid.U...|2024-01-01 00:39:00|   AMD|   Neutral|
# |{__class__=uuid.U...|2023-12-28 14:23:00|  AAPL|  Positive|
# |{__class__=uuid.U...|2023-12-29 22:26:00|  GOOG|  Positive|
# |{__class__=uuid.U...|2023-12-29 16:03:00| GOOGL|   Neutral|
# |{__class__=uuid.U...|2023-12-30 15:39:00|  AAPL|   Neutral|
# |{__class__=uuid.U...|2023-12-28 21:12:00|    BA|  Positive|
# |{__class__=uuid.U...|2023-12-29 16:55:00|   CVX|  Positive|
# +--------------------+-------------------+------+----------+
# only showing top 20 rows

# %%
table_name_pred = "prednews"

create_table_query = f"""
    CREATE TABLE IF NOT EXISTS {table_name_pred} (
        timestamp TIMESTAMP PRIMARY KEY,
        symbol TEXT,
        prediction TEXT
    )
"""

session.execute(create_table_query)

for row in new_dataframe.rdd.collect():
    
    insert_query = f"""
        INSERT INTO {table_name_pred} (timestamp, symbol, prediction)
        VALUES ('{row.timestamp}', '{row.symbol}', '{row.prediction}')
    """
    session.execute(insert_query)

session.shutdown()
cluster.shutdown()

# %%
new_dataframe.select("id").first()
# Out:
# Row(id='{__class__=uuid.UUID, int=302316883395429105585825085843689189883}')

# %%
session.shutdown()
cluster.shutdown()
